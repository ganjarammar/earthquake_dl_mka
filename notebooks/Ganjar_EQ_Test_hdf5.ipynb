# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Eq_Detection
# Out:
# /content/drive/MyDrive/Colab Notebooks/Eq_Detection

# %%
# !pip install -e EQTransformer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/Eq_Detection/EQTransformer
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached obspy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.3 MB)
# ...
#   Attempting uninstall: obspy
#     Found existing installation: obspy 1.4.0
#     Uninstalling obspy-1.4.0:
#       Successfully uninstalled obspy-1.4.0
#   Running setup.py develop for EQTransformer
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Eq_Detection
# Out:
# /content/drive/MyDrive/Colab Notebooks/Eq_Detection

# %%
from EQTransformer.core.trainer import trainer
trainer(input_hdf5='./EQTransformer/ModelsAndSampleData/100samples.hdf5',
        input_csv='./EQTransformer/ModelsAndSampleData/100samples.csv',
        output_name='./test_eqt/test_trainer',                
        cnn_blocks=1,
        lstm_blocks=1,
        padding='same',
        activation='relu',
        drop_rate=0.2,
        label_type='gaussian',
        # add_event_r=0.6,
        # add_gap_r=0.2,
        # shift_event_r=0.9,
        # add_noise_r=0.5, 
        mode='generator',
        train_valid_test_split=[0.70, 0.10, 0.20],
        batch_size=128,
        epochs=10, 
        patience=10,
        gpuid=None,
        gpu_limit=None)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 6000, 3)]    0           []
#
#  conv1d_31 (Conv1D)             (None, 6000, 8)      272         ['input[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 3000, 8)     0           ['conv1d_31[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 3000, 16)     1168        ['max_pooling1d_7[0][0]']
#
#  max_pooling1d_8 (MaxPooling1D)  (None, 1500, 16)    0           ['conv1d_32[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 1500, 16)     1808        ['max_pooling1d_8[0][0]']
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 750, 16)     0           ['conv1d_33[0][0]']
#
# ...

# %% [markdown]
# ## Test

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/My Drive/Colab Notebooks/Eq_Detection/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Eq_Detection

# %%
input
# Out:
# <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x7f79386e5190>>

# %%
from EQTransformer.core.trainer import trainer

trainer(input_hdf5= 'chunk2_ev.1069.hdf5', input_csv= 'chunk2_ev.1069.csv', output_name='test_trainer_0', cnn_blocks=2, lstm_blocks=1, padding='same', activation='relu', drop_rate=0.2, label_type='gaussian', add_event_r=0.6, add_gap_r=0.2, shift_event_r=0.9, add_noise_r=0.5, mode='generator', train_valid_test_split=[0.60, 0.20, 0.20], batch_size=20, epochs=10, patience=2, gpuid=None, gpu_limit=None)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input (InputLayer)             [(None, 6000, 3)]    0           []
#
#  conv1d_33 (Conv1D)             (None, 6000, 8)      272         ['input[0][0]']
#
#  max_pooling1d_7 (MaxPooling1D)  (None, 3000, 8)     0           ['conv1d_33[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 3000, 16)     1168        ['max_pooling1d_7[0][0]']
#
#  max_pooling1d_8 (MaxPooling1D)  (None, 1500, 16)    0           ['conv1d_34[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 1500, 16)     1808        ['max_pooling1d_8[0][0]']
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 750, 16)     0           ['conv1d_35[0][0]']
#
# ...
